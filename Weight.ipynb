# %%
import pandas as pd

df = pd.read_csv("/home/ubuntu/Documents/health/weight.csv")

# %%
daily = df.groupby('Date').sum()

# %%
daily.columns

# %%
from IPython.display import display, HTML
display(HTML(daily.to_html()))

# %%
daily.plot()
